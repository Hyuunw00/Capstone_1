# %% [markdown]
# 참조: https://lovit.github.io/nlp/2019/04/30/textrank/

# %%
import pandas as pd
import glob

# %% [markdown]
# ## 데이터 로드 및 긍정, 부정 나누기
# - 긍정, 부정 분류된 csv 파일을 불러와 긍정, 부정을 나눠 저장
# - 긍정 리뷰와 부정 리뷰의 비율에 따라 평점 부여

# %%
path = './분류리뷰'

file = glob.glob(path + "/*.csv")
data = []

for root in file:
    data.append(pd.read_csv(root, encoding = "cp949"))
    
data[0].head()
# Out:
#    Unnamed: 0                                             review  y
# 0           0                 냄새를 쓱 맡아보니 매콤하면서도 먹음직스러운 향이 코를 스친다  1
# 1           1  까르보나라 파스타 먹을 때 꾸덕한 크림소스가 잘 묻을 수 있도록 링귀니를 사용하는 ...  1
# 2           2                    불닭볶음면은 너무 맵지만 까르보불닭볶음면은 딱 좋은 맵기  1
# 3           3             매운맛의 원조 불닭소스와 크림분말이 만나서 부드럽게 즐기실 수 있어요  1
# 4           4                    이 두가지 조합이 매운맛을 덜어주는데 큰 공신을 한다구욧  1

# %%
pos = []
neg = []
star = []  #평점을 부여할 변수

for i in range(20):
    data[i] = data[i].loc[:, 'review':'y']
    tmp_pos = data[i][data[i]['y'] == 1]
    tmp_neg = data[i][data[i]['y'] == 0]
    pos.append(tmp_pos)
    neg.append(tmp_neg)
    
    score = len(tmp_pos) / 20 * 10
    star.append(score)
    
pos[0].head()
# Out:
#                                               review  y
# 0                 냄새를 쓱 맡아보니 매콤하면서도 먹음직스러운 향이 코를 스친다  1
# 1  까르보나라 파스타 먹을 때 꾸덕한 크림소스가 잘 묻을 수 있도록 링귀니를 사용하는 ...  1
# 2                    불닭볶음면은 너무 맵지만 까르보불닭볶음면은 딱 좋은 맵기  1
# 3             매운맛의 원조 불닭소스와 크림분말이 만나서 부드럽게 즐기실 수 있어요  1
# 4                    이 두가지 조합이 매운맛을 덜어주는데 큰 공신을 한다구욧  1

# %%
neg[0].head()
# Out:
#                                             review  y
# 17         까르보 불닭볶음면 컵라면은 매운 향에 비해 매운 맛이 강하지는 않았어요  0
# 18  입맛이 무뎌서 그런지 크림맛이 잘 느껴지지는 않았지만 적당히 맵고 부드러운 맛이에요  0

# %% [markdown]
# ## 키워드 추출
# - https://github.com/lovit/textrank
# - 문장을 형태소 단위로 분류한 후 textrank를 사용하여 키워드 추출 (명사, 동사 등의 형태소를 골라서 적용)
# - 키워드가 아닌 단어 제외 (라면 이름 -> 제조업체 -> 감상 -> 비교 -> 기타 순서)
# - 긍정, 부정 각각 상위 3개의 키워드 추출

# %%
from textrank import KeywordSummarizer
from konlpy.tag import Komoran

komoran = Komoran()

def komoran_tokenize(sent):
    words = komoran.pos(sent, join=True)
    words = [w for w in words if ('/NN' in w or '/XR' in w or '/VA' in w or '/VV' in w)]
    return words

def get_keywords(df):
    sents = df['review'].tolist()
    if len(sents) == 0:
        sents = ["라면 라면 라면 라면 라면 라면 라면 라면 라면 라면 라면 라면"]
    
    keyword_extractor = KeywordSummarizer(tokenize = komoran_tokenize, min_count = 1, window = -1, verbose = False)
    keywords = keyword_extractor.summarize(sents, topk=30)
    key = []
    for word, rank in keywords:
        word = word.split("/")[0]
        if len(word) > 1:
            key.append([word, round(rank, 2)])
            
    return key

# %%
pos_keyword = []
neg_keyword = []

for i in range(20):
    if len(pos[i]) > 0:
        key = get_keywords(pos[i])
        pos_keyword.append(key)
    else:
        pos_keyword.append([])
        
    if len(neg[i]) > 0:
        key = get_keywords(neg[i])
        neg_keyword.append(key)
    else:
        neg_keyword.append([])

# %%
sub = ["불닭", "무파마", "짜파게티", "미역국", "스낵면", "신라면", "블랙", "진라면", "왕뚜껑", "컵누들", "라면", "봉지", "농심", 
       "오뚜기", "팔도", "느낌", "라고", "생각", "괜찮", "맛있", "강하", "모르", "좋아", "그렇", "이랑", "어울", "비하", "다면", 
       "사실", "정도", "그때", "비비", "보이", "이전", "구매", "들어"]

positive = []
negative = []

for item in pos_keyword:
    string = ""
    cnt = 0
    for key in item:
        for cond in sub:
            if cond in key[0]:
                break
        else:
            string += "#" + key[0] + " "
            cnt += 1
            
        if cnt == 3:
            break
    
    if string == "":
        string = "리뷰 데이터 부족ㅠㅠ"
    positive.append(string)
    
for item in neg_keyword:
    string = ""
    cnt = 0
    for key in item:
        for cond in sub:
            if cond in key[0]:
                break
        else:
            string += "#" + key[0] + " "
            cnt += 1
        
        if cnt == 3:
            break
    
    if string == "":
        string = "리뷰 데이터 부족ㅠㅠ"
    negative.append(string)

# %%
idx = 0

positive[idx], negative[idx]
# Out:
# ('#소스 #크림 #매운맛 ', '#부드럽 #느끼 #크림 ')

# %% [markdown]
# ## 서버에 저장하기 위한 출력
# - 리뷰: @@ 단위로 구분하여 줄바꿈
# - 키워드: 각 긍정 키워드, 부정 키워드 칸에 저장
# - 평점: 평점 칸에 저장

# %%
sent_pos = []
sent_neg = []

for i in range(20):
    p = ""
    n = ""
    for item in pos[i]['review']:
        p += item + "@@"
    for item in neg[i]['review']:
        n += item + "@@"
    
    if p == "":
        p = "긍정 리뷰 데이터가 부족해요ㅠㅠ"
    if n == "":
        n = "부정 리뷰 데이터가 부족해요ㅠㅠ"
        
    sent_pos.append(p)
    sent_neg.append(n)

# %%
name = ['까르보불닭볶음면', "나가사끼짬뽕", "무파마", "미트스파게티불닭볶음면", "비빔면", "사천짜파게티", "새우탕", 
        "쇠고기미역국라면", "스낵면", "신라면건면", "신라면두부김치", "앵그리짜파구리", "오라이시", "진라면", "짜파게티범벅", 
        "짬뽕왕뚜껑", "참깨라면", "컵누들매콤", "컵누들베트남쌀국수", "크림진짬뽕"]

for i in range(20):
    print("=" * 50)
    print(name[i])
    print("=" * 50)
    print("-긍정리뷰-")
    print(sent_pos[i])
    print("-긍정키워드-")
    print(positive[i])
    print("-부정리뷰-")
    print(sent_neg[i])
    print("-부정키워드-")
    print(negative[i])
    print("-별점-")
    print(star[i])
# Out:
# ==================================================
# 까르보불닭볶음면
# ==================================================
# -긍정리뷰-
# 냄새를 쓱 맡아보니 매콤하면서도 먹음직스러운 향이 코를 스친다@@까르보나라 파스타 먹을 때 꾸덕한 크림소스가 잘 묻을 수 있도록 링귀니를 사용하는 것처럼 까르보불닭볶음면의 면발도 납작해서 한 젓가락 들었을 때 꾸덕한 소스가 같이 딸려 나오는 것이 참 좋다@@불닭볶음면은 너무 맵지만 까르보불닭볶음면은 딱 좋은 맵기@@매운맛의 원조 불닭소스와 크림분말이 만나서 부드럽게 즐기실 수 있어요@@이 두가지 조합이 매운맛을 덜어주는데 큰 공신을 한다구욧@@저같은 맵찔이가 아니시라면 참치마요 대신 전주비빔을 추천드려요@@내 기준에는 그래도 충분히 꾸덕꾸덕하게 느껴진다@@크림이 들어가면 느끼한 맛이 있을 것 같은데  매운 불닭볶음면 소스와 만나니 둘이 너무 잘 어울린다@@불닭볶음면 먹을 때 한번씩 멍때리며 찾아보기 좋을 것 같다@@약간 다른 라면이랑 확실히 면 자체도 특이하게 생기지 않았나요@@삼양식품의 운명을 바꾼 불닭볶음면 시리즈에 대한 내용이 너무 인상적이었기 때문@@다양한 연령층에게 어필할 수 있을 것으로 예상@@치즈가루와 부드럽고 매콤한 소스의 조화가 아주 좋다@@내 기준 까르보불닭볶음면은 살짝 덜 익어서 꼬들한 면 상태일 때 먹는 게 더 맛있는 것 같다@@불닭 시리즈는 다 맛있고 매워요@@확실히 매운맛에 크림이 들어가니까 적당히 매우면서 감칠맛이 함께 나는 편이었다@@동생이 맵린이라 이걸로 불닭 입문해서 맨날 먹던 적이 있었는데 확실히 크림이 들어가니까 매운 거 잘 못 먹는 사람들도 맛있게 먹기 좋은 맛이다@@까르보 같이 먹을 까르@@
# -긍정키워드-
# #소스 #크림 #매운맛
# -부정리뷰-
# 까르보 불닭볶음면 컵라면은 매운 향에 비해 매운 맛이 강하지는 않았어요@@입맛이 무뎌서 그런지 크림맛이 잘 느껴지지는 않았지만 적당히 맵고 부드러운 맛이에요@@
# -부정키워드-
# #부드럽 #느끼 #크림
# -별점-
# 9.0
# ==================================================
# 나가사끼짬뽕
# ==================================================
# -긍정리뷰-
# 맵찔이도 충분히 맛있게 먹을 수 있을 정도로 많이 맵지는 않아요@@재구매 의사  있음@@최고지 맛있다@@그래도 오리지널 틈새보다는 안매운것같고 맛있다는 느낌을 계속 가지고 먹을 수 있었음@@해물의 시원함은 모르겠지만 마른 오징어가 들어있다는 건 내가 확실히 알겠다@@더 해물  하던가 더 사골  하던가 더 칼칼  하던가 세개가 다 이도저도 아니게 애매한 느낌   아 이번 시리즈가 진짜 마지막이었으면 좋겠군@@조미료가 절대 나쁜게 아닌걸 알기때문에 다양한 조미료의 맛의 조합이 오히려 기대됩니다@@사골국물같은 진한 맛과 고소한 맛이 너무 좋네요@@가장 주의깊게 볼 점 건더기가 정말 풍부하다는 겁니다@@문어도 쫄깃쫄깃하게 잘 익었어요@@면발이 통통한게 맛있었습니다@@적당하게 매워서 매운음식 매니아와 못 먹는 사람도 다 먹을 수 있을 것 같았어요@@얼큰 칼칼한 국물 풍부한 건더기@@밥과 함께 먹기 좋은 라면 식생활빈부격차 해소에 기여 실 짬뽕 대비 믿기지 않은 맛 재현율     이 라면은 옛날부터 5점이었습니다@@나가사끼 짬뽕은 국물이 매콤해서 넘 좋다@@라면 너무좋아 어또캐@@
# -긍정키워드-
# #해물 #이도 #쫄깃
# -부정리뷰-
# 2  별로 안매운데@@먹다보니 약간 느끼하기도 한거 같고@@결국 다 먹지 못하고 남겼습니다@@점심으로 먹기엔 큰컵도 부족하지만@@
# -부정키워드-
# #부족 #점심 #느끼
# -별점-
# 8.0
# ==================================================
# 무파마
# ==================================================
# -긍정리뷰-
# 뭐랄까 라면하면 시원한 파맛이 최고죠@@그맛에 해장으로 라면을 많이 찾기도 하잖아요@@표지 이미지에 맞게 시원한 요소는 거의 때려박은 느낌@@그래서인지 확실히 개운한 느낌은 잘 와닿았고  해장 땡길때도 좋겠네 싶긴했는데@@무파마탕면 큰사발면 시원한 육수분말라고 적혀있습니다@@해장용으로도 괜찮을 것 같네요@@하지만 아들 성의가 있으니  살짝 만 덜 끊였으면 좋았을걸 하고 시식을 해 봅니다@@맵기나 짠맛은 조금 약한편 같아요@@다만  먹다보면 밥이 너무 말아먹고 싶은 유혹이 드는데 다이어트할땐 탄수화물 폭탄 조심@@신기한데 좋습니다  개인적으로 무를 그렇게 좋아하진 않는데 무파마는 무랑 파맛이 꽤 국물육수를 잘 살려준다고 생각하기 때문이예요  건강에도 좋구@@국물육수는 나름의 맛이 있어요  먹다보면 파와 무의 맛이 느껴져요@@무는 특히 씹는 느낌이 좋았네요1@@좀더 맛을 풍부하게 해서 먹을 수 있다고 생각하거든요@@컵라면도 좋지만  무파마의 맛을 더 풍부하게 느끼는 건 봉지라면으로@@하지만 이번에 건더기를 푸짐하게 저도 따로 준비해서 먹었다는거@@느끼한거 같기도하고@@봉지에 적혀있는대로 건더기가 많은 편의 라면이라@@이렇게 먹어주면 배부르고 좋습니다@@
# -긍정키워드-
# #육수 #국물 #시원
# -부정리뷰-
# 한번에 연달아 2개는 먹지마세요@@그때는 느끼할 수도@@
# -부정키워드-
# #느끼 #연달 #한번
# -별점-
# 9.0
# ==================================================
# 미트스파게티불닭볶음면
# ==================================================
# -긍정리뷰-
# 이색적로 맛볼만한 붉닭시리즈 신제품 진한 풍미와 토마토소스의 새콤함@@약간 토마토 맛이 나면서 적절히 매콤하고  치즈 분말 때문인지 치즈 맛도 나서 맛있다@@매워서 매실로 입가심을@@음  까르보 불닭볶음면이 매운 크림파스타 맛이라면  미트 스파게티 불닭볶음면은 매운 토마토스스파스타 라고 생각하시면 될 것 같습니다 불닭맛 보다는 스파게티에 가깝구요  불 스파게티라고 생각하시면 됩니다 엄청 매운건 아니니까 토마토소스 스파게티를 좋아하신다면 맛있게 드실 수 있을 것 같아요@@매운향이 코끝을 뙇     파마산 치즈가루같은 느낌의 분말스프도 넣어주었어요@@삼양이 아주 열일하네요 불닭 관련 신제품이 막 나오는 것 같아요@@매콤함만 있으면 다 잘 될거라고 생각하고 만든 라면인것 같다@@한국인은 뼈를 깎는 매운맛을 좋아하니까@@자  그럼 마지막에 요렇게 맛있는 라면이 탄생합니다 라면도 꼬들꼬들하게 아주 잘 익었죠@@미트 스파게티와 불닭의 조화라니 맵고 감칠맛나는 스파게티맛이려나@@그렇다고 맛없는건 아니다@@
# -긍정키워드-
# #스파게티 #토마토 #소스
# -부정리뷰-
# 치즈의 향이나 꾸덕꾸덕한 느낌은 강하지않아요@@하지만 달달한 맛을 기대한 다면 실망할지도 모른다 그렇게 단맛이 강하지 않다@@저는 굉장히 실망스러웠어요@@그리고 그냥 이럴거면 불닭을 먹겠어요@@맵긴 매운데 스파게티 맛은 거의 안나는@@그냥 봉지만 봐도 대충 무슨 맛일지는 알 수 있도록 되어있죠  스파게티   불닭입니다@@문제는 맛도 별로 다르지 않다는 것@@맛은 있는데 크게 차이를 못느끼겠더라구요@@음  먹을만은 한데음@@
# -부정키워드-
# #스파게티 #실망 #기대
# -별점-
# 5.5
# ==================================================
# 비빔면
# ==================================================
# -긍정리뷰-
# 그렇지만  면이 거의 물 붓는 선까지 올라와 있다는 것 에 확실히 양이 늘었다는 것을 느꼈다@@무가 들어간 소스여서 그런지 확실히 시원하고  매운건 팔도비빔면보다 살짝 매운 수준인 라면이었습니다@@생각보다 심플하고 맛있었다@@아주 기름진데 단짠의 맛이었다@@비빔면은 차갑게 먹어야 제맛인데 이건 어쩔수없이 따뜻 하게 먹어야하는거라 과연 괜찮을까하는 의구심을 갖고 도전해보았다@@그냥 밖에만 나와도 조흠@@차 뒷자석 접어서 트렁크부터 돗자리깔고 파도소리에 누워서 노래듣는 여유로움 가만히만 있어도 좋아요@@갑자기 비빔면이 꼭 먹고 싶은 날이 있어요@@하나 반 정도로 더 먹고 싶다는 생각을 했답니다@@원래 봉지라면으로 입맛없을때 새콤달콤한맛 땡길때 굉장히 자주먹었거든요@@이미지를 보기만 해도 굉장히 새콤달콤 할것만 같더라구요@@입맛없을때@@그리고  개인적인 생각이지만  봉지라면으로 먹었을때가 더 새콤달콤한 맛이 더 잘 느껴지고  면도 더 탱글해서 확실히 더 맛있다해야하나@@이왕 먹는거 셋뚜로 같이 먹어보는게 좋지 않겠어요@@덕분에 다먹고 배가 터졌습니다@@상상이 가시나요  비빔면 진짜 괜찮았어요@@너무 맛있어서 내일 하나 더 먹을 예정이다@@
# -긍정키워드-
# #느끼 #도전 #차갑
# -부정리뷰-
# 나 불쌍해   근데 사실 라면 엄청 좋아해서 식사 퀄리티에 비해 만족도는 높은 편@@3 소스 자체만 먹었을때는 매콤함이 많이 사라진 느낌이어서 그런가 약간 밍밍한 느낌이 강했음@@저는 다이어트 중이라 양이 적당하고 맛있다고 생각했는데  조금 아쉽기도 했어요@@
# -부정키워드-
# #불쌍 #식사 #만족도
# -별점-
# 8.5
# ==================================================
# 사천짜파게티
# ==================================================
# -긍정리뷰-
# 저는 라면을 좋아하는데 그중에서도 짜파게티를 좋아합니다@@개인적으로는 일반 짜파게티가 더 맛있는 것 같다능@@면 면은 기존 짜파게티의 면과 동일합니다 신라면보다 조금 더 통통한 것 같고 너구리보다는 덜 통통해 보입니다 후레이크는 기본으로 들어가 있기 때문에 안 보인다고 찾을 필요 없습니다@@여러분 중 중화요리 집에가서 짜장면을 먹을때 고춧가루를 뿌려드시는 분들이 있으시죠@@그렇게 먹으면 짜장면 다먹을때쯤 느끼한 맛도 없고 감칠맛이 나서 더 맛있게 먹었던 기억이 있어요@@제가 좋아라하는 사천짜파게티@@저는 개인적으로 신김치보다 이렇게 약간 익기전 아삭아삭한 김치랑 깍두기 식감이나 맛을 좋아하거든요@@끓여먹는 것보다는 안 맵다@@전혀  하나도  매운게 1도 안느껴지는데@@아마 매운맛을 담당하는 요소가 있어서 그럴듯@@사천짜파게티 매콤한 사천이라고 써있습니다@@면을 보았는데 건더기는 면 밑에 들어있나봅니다@@확실히 일반 짜파게티랑은 다르게 사천짜파게티의 특유의 매콤한 맛은 났습니다@@끝맛은 고추기름의 매콤함  이 느껴지는 조합이예요@@먹어보면 확실히 짭쪼름 포만감이 느껴지는 맛이기에   그래도 일단 맛은 좋고   헣@@이번만큼은 큰맘 먹고 새로 나온 신상에 도전을 해보기로 했습니다@@컵라면 먹으면 보통 2 3개씩 한꺼번에 먹다 보니 살짝 느끼한 감이 있어서 매콤한 사천 짜파게티가 끌리 더라구요@@
# -긍정키워드-
# #매콤 #사천 #짜장면
# -부정리뷰-
# 그냥 보통 짜파게티는 심심한 느낌이잖아요@@생각보다 매콤한맛이 1도 없어서 당황@@맛은 당연히 기본적으로 짜파게티인데 이게 끝맛이 살짝 매콤  해요@@
# -부정키워드-
# #매콤 #기본 #당황
# -별점-
# 8.5
# ==================================================
# 새우탕
# ==================================================
# -긍정리뷰-
# 양도 진짜 많은 편이에요@@국물도 더 진해진 느낌이에요@@저도 이거 해장으로 먹었어요@@이건 적당히 칼칼하고 해물 특유의 맛이 시원해서 해장라면으로 딱이더라구요@@저는 저게 그렇게 맛있더라구요@@요즘에 여기저기 맛있고 신기한 라면이 많이 나오다 보니까 농심 새우탕 라면에 소홀하고@@개운한 안성탕면 같은 라면 좋아하시면 새우탕도 강추요@@누룽지 구수함 고소함이랑 컵라면도 잘 어울림 밥대용으로도 가능 간만에 먹으니까 농심 새우탕 역시 명불허전 존맛@@면을 제외하고 국물은 정말 비싼 만큼 값을 했어요 농심 새우탕보다 찐 하고 더 깊은 바다의 맛  짠맛 입니다@@그러고 보면 짜파게티랑 거의 흡사한 맛의 제품도 있어서   겨울에 먹어봤는데 맛이 거의 비슷하고 차이점은 오뚜기가 롯데슈퍼 입구에서 싸게 팔고 먹은 후에 덜 느끼했다는 점  맛도 카피하는 가 봄@@집에서 라면에 마른 미역을 넣어 먹으면 세척을 덜한 특유의 미역 짠내와 약간의 미역 비린내같은 게 나거든요@@새우탕은 부속물들이 맛있다@@튀김과 소스 조합이 정말 맛있습니다@@맵거나 하진 않고  칼칼함은 있었음@@큰컵은 폴리  용기인데  소컵은 종이 용기라 개인적으로는 더 좋은 것 같아요@@큰컵보다 소컵의 면빨이 더 얇고 쫄깃한 느낌이에요@@야식으로 이거 하나만 먹거나  국물용으로 밥이랑 먹거나  해장하거나   작은 양에  더 싼 가격  더 맛있는 맛으로 최고@@
# -긍정키워드-
# #새우 #미역 #국물
# -부정리뷰-
# 그냥 새우 향이 좀 나고 해산물 향이 나는 것 같은데@@이전에 새우탕 컵라면은 먹다 보면 금새 면이 불어서 꼬들파인 저는 아쉬웠거든요@@음 그냥 그렇다구요@@
# -부정키워드-
# #새우 #파이 #아쉽
# -별점-
# 8.5
# ==================================================
# 쇠고기미역국라면
# ==================================================
# -긍정리뷰-
# 면에 쌀가루가 들어갔다고 하는데 그래서 인지 면이 더 맛있는 것 같기도 하고요@@간식으로 종종 먹기 좋을 것 같습니다@@미역과 함께 건조 소고기도 탱탱하게 불어오르고요@@그런데도 미역국 맛이 진하게 나면서 저는 개인적으로 굉장히 맛있게 먹었어요@@쇠고기 양지와 진한 사골 국물이 우러나왔다는데 맛 보면 알겠지@@먹다보면 살짝 느끼해서 김치필수 매콤한 라면에도 김치는 필수이긴 하죠@@밥 말아 먹으면 은근 든든할 것 같아요@@국물은 진한 미역국 색깔이었고 면은 살짝 얇은 굵기의 면발이었습니다@@얼른 먹을 수 있어서 좋았고 바로 면발을 건져서 맛을 보았어요@@미역국을 라면으로 먹을 수 있다니@@역시 라면은 빨갛고 매콤한 라면이 최고로 맛있는 것 같아요@@엠보싱같은 보송보송함에 용기가 덜 뜨겁게 느껴지는 장점도 있는 것 같아요@@총 60g  235kcal로 당류도 적고  다이어트할 때 먹어도 좋겠어요@@그리고 건조미역 건더기가 엄청 많이 들었어요@@조각미역의 양이 많아서 초록 느낌이 물씬 풍기는 겁니다@@생각보다 건더기가 굉장히 실해서 기대 이상으로 만족스러웠어요@@먹어보니 꽤 쫄깃한 식감까지 제대로 살려서 가성비 좋게 한 끼를 맛있게 먹었어요@@슈혀느님은 면   좋아해요@@오뚜기에서 쇠고기 미역국 라면이 나왔을때   처음 보고서는 미역국이 라면하고 어울릴까싶어   정말 특이하다 싶었어요@@면하고 미역국 국물이 안어울릴거라 생각했는데   예상외로 너무 잘 어울려요@@
# -긍정키워드-
# #미역 #국물 #쇠고기
# -부정리뷰-
# 부정 리뷰 데이터가 부족해요ㅠㅠ
# -부정키워드-
# 리뷰 데이터 부족ㅠㅠ
# -별점-
# 10.0
# ==================================================
# 스낵면
# ==================================================
# -긍정리뷰-
# 스낵면을 여니까 안에는 후레이크랑 분말스프가 들어있더라고요@@오호 너무 좋았어요@@밥말아먹으면 맛있을듯  밥이 없어서 아쉬웠어용@@용기뚜껑에 밥말아먹을때 가장 맛있는 라면 이라고 되어있네요@@아직도 카피 라이팅이 밥 말아 먹으면 가장 맛있는 라면으로 밀고 있네요@@개인적으로는 술 먹고 다음날 이런 순한 국물이 더 좋을 거 같습니다@@스낵면   처음 먹는데 면발이 얇아서 약간 육개장 컵라면이 생각났어요@@mashed potato 도 구매하려고 했는데 다 안먹을꺼 같아서 양이 좀 적은 포테이토를 구매해왔어욘 요건 2900원@@부셔먹을때 맛있던  라면  스낵면@@짧게 결론만 말씀드리면  맛있었어요   매운라면 못드시는 분들에게   그리 느끼하지 않아요     딱일 것 같네요@@면발이 상당히 가늘어요@@1 가는 면발의 컵라면을 좋아하시는 분@@5 미역국컵라면이 너무 느끼해 약간 더 간이 된 컵라면을 드시고 싶은분@@10 맵지않은 컵라면 찾으시는 분@@그래도 맛있게 먹으려면  나트륨 걱정은 넣어두고 스프를 다 넣습니다@@저는 개인적으로 진라면이 제 입에 맞고   어머니께서는 스낵면을 좋아하시네요@@스낵면은 스펀지 방송프로 에서 국내의 라면 미각 전문가라는 사람들을 모아 놓고 밥을 말아 먹으면 가장 맛있는 라면을 찾는 실험을 했는데   거기서 1위로 선정되었습니다@@한줄평으로는 스낵면 컵라면   성질급한 한국인에게 제격이다   매운맛은 덜하구     입니다@@
# -긍정키워드-
# #개인 #느끼 #국내
# -부정리뷰-
# 면이 잘 불지 않아서 참좋습니다만  먹다보면 면이 약간 늘어지는 느낌은 있습니다@@맛은 일단 맵진 않고 약간 짭짤한 느낌이 있어요  그리고 생각보다 느끼하지 않아요@@
# -부정키워드-
# #늘어지 #느끼 #짭짤
# -별점-
# 9.0
# ==================================================
# 신라면건면
# ==================================================
# -긍정리뷰-
# 국물도 시원하고 너무 맛있었어요@@신라면 건더기가 큼지막 넘좋네요@@면도 면이지만  국물도 너무 맛있었어요@@국물도 기존 오리지널 보다 덜 매워지고 맛이 깊어진 느낌 매우 맛있음@@그래서 맛있게 먹고도 285칼로리@@처음엔 튀긴 면이 아니라서 기름의 고소함이 적겠다 싶었는데 왠걸@@재구매의사 100 이고 쟁여놓고 라면 생각날때마다 이제 건면으로 부담없이 챙겨먹으려구요@@컵라면과 봉지라면 맛은 아주 유사하고  면발 두께도 비슷해요@@저는 감자면 좋아해서 마음에 들더라구요@@신라면 건면 후레이크는 좀 신경을 썻네요@@다이어트를 하면서부터는 국물은 적이다@@면도 약간 더 쫄깃한것 같아요@@285칼로리의 라면이라니 국물은 당연히 제외하고 저 칼로리이지 않을까 예상해보는데요@@우리가 보통 라면 먹을 때 생각하는 꼬들 쫄깃의 식감이 아니라는 점만 빼면 그냥 라면과 비슷했어요@@칼로리도 신경 쓰고  깔끔하고 얼큰한 국물이 생각날 때 또 먹어야겠어요@@기름기가 덜해서 담백한 편이예요@@
# -긍정키워드-
# #국물 #칼로리 #비슷
# -부정리뷰-
# 2후레이크 양이 적다@@단점이라하면  생라면으로 먹긴 별로라는 점@@면발에 국물이 잘 스며드는 편은 아닌 것 같다@@양도 적은데 사실 1500원이면 좀 비싼것같네요@@
# -부정키워드-
# #단점 #양도 #비싸
# -별점-
# 8.0
# ==================================================
# 신라면두부김치
# ==================================================
# -긍정리뷰-
# 국물 자체가 김치찌개 맛이 강하다 보니 밥을 부르는 맛입니다@@살짝 국물이 졸여져서 약간 매콤하면서 짠 느낌도 있지만 김치전골 오래 끓으면 느껴지는 그런 맛이에요@@다만 식감은 또렷이 기억난다 센 불에 팔팔 끓여 건져 낸 순두부 같은 느낌  한마디로 흐물흐물이다 아  건김치의 경우에는 그런대로 식감이 살아있다@@면도 컵라면보다 훨씬 쫄깃하고 탱글하고 맛잇다@@쫄깃쫄깃한 면발이 맛있네요@@표고버섯 냄새가 나지 않는 것이 수상하여 찍어먹어보니 시큼한 김치향이 강렬합니다@@외국인이라면 정말 새롭게 맛있어 할 거 같단 생각이 들었다@@일단 제가 사실 김치관련 라면을 참으로 좋아하기 때문에 저에게 희소식이었는데 말이죠 토종 한국인이에요@@김치 없이도 맛있게 먹을 수 있는 컵라면  정말이지 다양한 전쟁    속에서 살아남으려면 뭔가 독특한 나만의 브랜딩이 필요하다는걸 라면 먹으며 느껴봅니다@@국물에 밥 말아먹고싶어서 참느라 혼났다@@보들보들한 두부가 들어가서 맛있습니다@@면발이 진짜 맛있어요  우리가 컵라면 먹을때의 면과는 조금 다른 질감이라고 해야될까요@@자취생이다보니 평소 컵라면을 많이 먹는 편인데 칼로리도 500칼로리가 넘지 않기 때문에 국물을 먹지 않는다면 그리 부담되지 않기 때문이에요@@라면을 먹으면서 중간중간 씹히는 김치의 식감이 꽤나 매력적이었습니다@@사골 국물의 깊은 맛에 김치 맛이 더해진 느낌의 신라면 블랙 두부김치였습니다@@매울  신  한자가 얼핏 보면  푸 라는 한글과 비슷해서 일명  푸라면  이라는 애칭도 있는 신라묜의 프리미엄 버전인 신라면 블랙  여기에 두부김치가 더해진 신선한 만남인 신라면 블랙 두부김치라니 조합 자체도 신선하고 기대가 되더라구요@@내용물은 생각보다 심플해 보인다 싶었는데 요 면을 들춰보니 건더기들이 숨어있더라구요@@
# -긍정키워드-
# #김치 #국물 #두부김치
# -부정리뷰-
# 보다 보니 약간 해외를 겨냥 했을 수도 있겠다는 생각이 들기도 신라면은 너무 맵고 블랙은 고급스럽지만 뭔가 단조롭고 약간의 블랙 업그레이드 버전으로 생각하면 색다르고 괜찮은 도전 이라고 생각도 들었다@@개인적으론 신라면 시리즈의 장점이 부각되지 않은 신제품인 것 같았답니다@@두부는 약간 몰캉거리지만  이게 특별한 느낌을 주는 요소가 되지는 않았어요@@
# -부정키워드-
# #요소 #특별 #두부
# -별점-
# 8.5
# ==================================================
# 앵그리짜파구리
# ==================================================
# -긍정리뷰-
# 짜파게티의 특유의 짜장맛과 너구리의 얼큰하고 시원한 맛의 콜라보  여기 매콤한 풍미까지 더했어요1@@집에서 흔히 즐겨먹는 볶은김치도 먹을 수 있어서 좋은 거 같고요@@맛있는냄새  너구리향이 더 강한것같기도하고@@너무 맛있게 잘 먹은 앵그리 짜파구리 컵라면   다음 주에 글뤽 동생 놀러오면 매운거 좋아라하니까 먹어보라고 줘야겠어요@@글뤽네 친정아빠는 세계에서 제일 맵다는 고추도 맛있게 드시는 입맛이라 이건 안 매워 하실거 같긴하네요@@보통 짜장 컵라면들이  짜장라면 이지  짜장면 이랑은 많이 다른 맛인데    이 앵그리 짜파구리 컵라면은 진짜  짜장면 이랑 비슷해서 호불호없이 다들 좋아할 것 같아요@@그리고 짱짱이가 한 번 먹고 반했다고 이야기했던 앵그리 짜파구리까지 잊지않고 기억했다가 함께@@호불호없이 다 좋아할 맛이고 무엇보다 담백함보다는 달달함을 선호하시는 분들에게 더욱 추천합니다@@저는 사실 너구리 먹을때 다시마 안 먹는데  그거 드시는분들이 많더라구요@@솔직히 짜기도한데 밥이랑 같이 먹으니 넘나 맛있는거  친구 덕분에 달달함과 매콤짭짤함을 함께 느낄 수 있었더 좋은 조합이었습니다@@그래도 매운 맛이 나니까 느끼함 없이 잘 먹었다@@이래야 골고루 면발이 탱탱하게 잘 익는답니다@@평소에 매운걸 좋아하는 제가 느끼기엔 별 다섯개 중 네개@@
# -긍정키워드-
# #구리 #짜장면 #너구리
# -부정리뷰-
# 그래도 맵다는@@저는 이것도 모르고 그냥 사먹음@@맛은 있는데 좀 매워요@@주위에서 하도 뭐라그래서 매운거 좀 먹어보려하는데 저는 입에서부터 거부반응이 일어나서@@귀여운 너구리 토핑이 들어있어요     맛은  너구리가 불을 뿜고 있는 것 보고서 불닭볶음면처럼 강렬한 매운 맛일 줄 알았으나 그냥 매콤 하지도 않은  개인적으로는 앵그리 이름값에 비해서는 좀 밋밋했어요@@물이 찰랑찰랑 거릴정도로 많아서 이게 맞는건가 싶어서 좀 당황스럽긴했음@@스프 비율이 안 맞았는지 제 취향은 아니어서@@
# -부정키워드-
# #너구리 #강렬 #귀엽
# -별점-
# 6.5
# ==================================================
# 오라이시
# ==================================================
# -긍정리뷰-
# 국물은 맛있고 고수 향도 심하지 않아서 괜찮았다@@세일 안 해도 종종 생각 나면 사 먹을 정도@@너비는 넓은데 굵기는 얇아 부드러워요@@베트남쌀국수 다 좋은데@@개운한 뒷맛으로 담에 또 먹고싶어지지용@@가끔 새롭게 먹고픈 라면 찾으신다면@@열량은 470 kcal 정도구요  나트륨도 뭐 꽤 높은 국물 라면입니다@@저는 마늘을 좋아하는 편이라 괜찮았는데 마늘 싫어하시는 분들은 호불호 있을 수도 있겠어요@@국물 맛도 현지랑 비슷하고 면발도 보들보들 맛있었어요@@쌀국수 오라이시 맛있어서 추천이요@@가끔 사무실에서 나가기는 싫고 배달시키기엔 이미 늦었고 쌀국수는 먹고싶다하면 요거 먹어도 나쁘지 않을듯함@@저는 꽤 신선하고 괜찮았던 것 같아요@@오일을 미리 넣는다는게 특이하다고 느껴졌어요@@콜리 요약  장점  고수가 다른 제품들보다 맛이 조금 더 강합니다@@맛있는 쌀국수를 찾으신다면          쌀국수 추천드립니당@@포 인 쌀국구 맛이랑 완전 달라요  향신료 향 없음@@
# -긍정키워드-
# #쌀국수 #국물 #마늘
# -부정리뷰-
# 안에 무언가 건더기   가 들었는데 조금만 뜯으면 기름만 빠져나오고 나머진 잘 안나오는 현상이@@순후추라면은 사리곰탕면에 후추를 넣은 맛인데    후추 특유의 맛이 강해서 사실 후추를 별로 안좋아하는 저에게는 불호였습니다@@또 1 1은 그냥 못 지나치니까@@단점  생각보다 짠 국물   양이 적게 느껴질 수 있음@@
# -부정키워드-
# #후추 #단점 #국물
# -별점-
# 8.0
# ==================================================
# 진라면
# ==================================================
# -긍정리뷰-
# 국물도 얼큰하면서 시원했고 면발도 잘 익었네요@@적당한 넓이 덕분에 안정적으로 용기를 들을 수 있었습니다@@저는 이런 라면은 우유랑 먹는 걸 좋아합니다@@맵짠우유의 조합은 진짜 사랑 그 자체@@면발이 더 쫄깃쫄깃하니 제 입맛엔 더 잘 맞더라구요@@가성비 컵라면@@진라면 큰컵 순한맛과 매운맛 입니다@@물론 더 맛있는 라면은 많지만 어디까지나 가성비 는 좋다구용@@바로바로                     제가 제일좋아하는 라면 1순위   진라면 매운맛@@역시나 맛은 매운편인 진라면 소컵 매운맛@@고기랑 버섯같은 것도 많았어요@@국물 맛은 봉지라면 진라면 매운맛이랑 매우 유사@@야채가 더 많아서 그런가 봉지라면 맛의 업그레이드라고 해도 될 것 같아요@@후레이크는 열었을 때부터 뿌려져있었고 안에 담겨있는 건 분말스프 하나@@이러면 뭔가 더 많이 느낌이라 좋음@@진라면 매운맛 평가는 5점 만점에 4점@@
# -긍정키워드-
# #매운맛 #쫄깃 #우유
# -부정리뷰-
# 순한맛은 국물 색이 이거보다 훨씬 연하더라구요@@일단 까봅시다@@스프뺴고 면발이나 다른건 다 똑같아유@@매운맛은 뭔가@@
# -부정키워드-
# #똑같 #연하 #국물
# -별점-
# 8.0
# ==================================================
# 짜파게티범벅
# ==================================================
# -긍정리뷰-
# 파김치에 닭고기랑 먹으니 더욱 맛있다@@약 3주째 다이어트하면서 5kg 감량한 나에게 작은 선물을 주려고 가장 먹고싶었던 음식을 하나 먹기로 했다@@이정도면 나쁘지않아    나트륨이 좀 있지만 다른 국물라면에 비하면 거의 1 2수준이더라 하하@@후레이크는 이미 뿌려져있음@@진짜진짜 맛있따@@봉지라면과는 사뭇 다른 스타일의 녀석@@짜다고 자기야@@날이 풀려서 좋네요@@건더기 스프 봉지가 따로 있지 않구요@@뭔가 국물있는 컵라면도 먹고싶은데 비벼벅는 컵라면도 먹고싶은 그런날@@얼큰한 국물도 땡기지만 짜장라면같은 그 특유의 꾸덕함도 먹고싶은 그런날 있잖아요@@그냥 술안주로 간편하게 먹기도 좋고 추운날 밖에서 먹기도 좋고 언제 먹어도 맛있는걸로는 육개장 사발면이 최고인것 같아요@@처음에는 어색할수가 있지만 조금씩 먹다 보시면 갑자기 밥을 비벼 먹고 싶은 충동이 강하게 밀려오실 거에요@@면만 먹었을 때는 심심할 수 있는 식감을 채워줘서 좋더라구요@@면발이 탱글탱글하다@@국물많은 컵라면보다 이렇게 국물은 적고 꾸덕꾸덕한게 맘에 든다@@내가 좋아하는 건더기@@
# -긍정키워드-
# #국물 #레이크 #뿌리
# -부정리뷰-
# 제 입맛에는 너무 느끼한편@@데피지 말고 그냥 먹어 봐야 겠네요@@이럴줄 알았으면 국물있는 일반 컵라면을 살걸 그랬어요@@
# -부정키워드-
# #일반 #국물 #이렇
# -별점-
# 8.5
# ==================================================
# 짬뽕왕뚜껑
# ==================================================
# -긍정리뷰-
# 짬뽕 왕뚜껑도  컵라면 뚜껑에 덜어서 먹는게 더 맛있더라@@꼬들꼬들 쫄깃한 면발을 좋아하는 분은 부지런히 드셔야 될 것 같아요@@아침에 귀찮을때 그냥 물끓여서 먹으면 되는게 아주 편한데요@@반면에 블랙컬러의 뉴짬뽕왕뚜껑은 안먹어봐도 매콤한 냄새가 나는듯하네요@@개인적으로 짬뽕왕뚜껑에 들어있는 얇은 면발을 선호하거든요@@청춘이니까 아프지마  참으로 좋은말이다@@팔도 왕뚜껑 컵라면의 특장점은 뭐니 뭐니해도 넓고 튼튼한 뚜껑이죠@@기존보다 더욱 화끈한 불맛  매운맛을 살린 리뉴얼 버전@@기존에 해물맛으로 달큰한 맛이 더 강했다면  NEW 버전은 화끈하고 얼큰한 맛에 집중했습니다@@짬뽕 왕뚜껑 컵라면도 다른 왕뚜껑 라면과 다를 거 없이 분말스프와 건더기스프가 있네요@@올앤만에 왕뚜껑 컵라면 먹으니 넘 맛있네요@@플라스틱 용기라 환경호르몬은 우려된다지만 직접적으로 뜨거운 국물이 닿는 건 아니니까@@면발이 쫄깃한 편이라 한 입 호로록 먹고 국물도 마셔주면 딱 맛있다@@개인적으로 왕뚜껑 짬뽕은 얼큰한 맛이기 때문에 여기에 김치보단 단무지가 더 잘 어울렸다@@보기 좋게 건더기스프와 분말스프를 잘 뿌려 줍니다@@건더기 스프가 잘 익을 수 있게 젓가락으로 조금 뒤적뒤적해줬어요@@팔도 컵라면 짬뽕 왕뚜껑은 왕뚜껑과 더불어 제가 좋아하는 컵라면 중 하나입니다@@475칼로리로 적당하게 느껴지는거 같습니다@@적당히 얼큰하면서 너무 자극적이지 않는 국물이 좋습니다@@
# -긍정키워드-
# #짬뽕 #스프 #국물
# -부정리뷰-
# 하지만 중식당에서 먹는 그런 짬뽕 국물을 생각하시면 안 돼요@@
# -부정키워드-
# #국물 #짬뽕 #식당
# -별점-
# 9.5
# ==================================================
# 참깨라면
# ==================================================
# -긍정리뷰-
# 참깨라면은 마냥 고소할줄만 알았는데 얼큰한 맛도 있어요  맵찔이인 저는 맵기도 했네요@@얼큰한 국물과 고소한 참깨가 생각날땐 참깨라면을 한번 드셔보세요@@맛있는 라면이지만 순두부 진짬뽕이라고 하면 순두부 할 맛@@액상스프랑 건더기스프가 들어있다@@신상라면 먹는것도 좋지만 역시 클래식이 한번씩 들어가줘야지   아마도 이젠 야근시리즈 끝@@참깨라면 컵라면 국물만@@국물만 먹어야딩@@면 대신 계란 건더기@@오뚜기 라면 참깨 컵라면 현대h몰 부담없이 넘 맛나게 먹기좋아요@@사발면 컵라면 왕사발 사이즈가 다양하지만   요 작은 사이즈   비상용으로 딱이에요@@그냥 버섯이랑 먹어도 넘 고소하고 칼칼하니 정말 맛나요@@나물이나 김치랑도 함께 먹으면 든든하죠@@가격 1000원               오뚜기 얼큰하고 더 고소해진 참깨라면 작은 컵라면입니다@@양념은 매운맛  고추  칠리    간장   양념분말   마늘 등이 섞여 들어갔어요@@맛있게 먹기@@요즘 나오는 신상라면들 보통 1500원정도하죠  에 비해 1200원의 가격대도 사악하지 않아서 참 좋고  스프 3개는 항상 칭찬합니다@@라면  틈  라면 등을 보면 봉지라면은 면이 굵고  컵라면은 면이 얇은 특성이 있는데   참깨라면은 한결같이 면이 얇은데 쫄깃합니다@@이름대로 참깨가 많이 들어가있고  계란블럭과 고추기름이 추가로 들어있어서 고소 한 맛 중에 고추기름의 얼큰함이 느껴지는 컵라면이에요@@
# -긍정키워드-
# #참깨 #얼큰 #고소
# -부정리뷰-
# 참기름 맛도 나고  맛은 괜찮은데 딱히 내스탈은 아니라서 자주 먹진 않을 것 같은데 나쁘진 않았음@@매운 라면 못드시는 분들께는 안맞을 수 있다는 생각입니다@@
# -부정키워드-
# #나쁘 #스탈 #참기름
# -별점-
# 9.0
# ==================================================
# 컵누들매콤
# ==================================================
# -긍정리뷰-
# 면에도 약간 간이 되어서 국물과 같이 간이좋다@@먹어보고 괜찮으면 더 구매하거나 다른 맛도 시도해 보거나 할 예정@@지방이 하나도 포함이 안 되어있는 것이 좋은 듯@@라면 느낌이 나서 라면 먹고싶을 때 상비해놓았다가 먹으면 좋을듯@@근데 매콤한 맛 좋아하시는 분들이라면 맛있게 드실거 같아요@@오뚜기 컵누들 매콤한맛@@역시 맛있음@@매콤하면서 은은한 탕 베이스로 다 어울림@@여러분 좋은 아침입니다@@맛 매콤한 맛@@분말스프 건더기 스프 넣어주고요@@컵누들 매콤한 맛은 국물이 다했다@@매콤한 음식이 너무 먹고 싶다@@1 후레이크와 분말스프 넣기@@컵누들의 가장 기초가 되는듯한 매콤한 맛@@마치 신라면 먹는 느낌 콜라겐으로 만든 면이라길래 크게 맛 없을 줄 알았는데 생각보다 매콤하고 맛있어서 놀랐네용@@은근 매콤해서 밤에 매콤한게 땡길때 하지만 칼로리 생각해서 고민 될때 너무 좋은것 같아요     일반 라면보단 위에 부담이 적어서 너무 좋았어요@@또한 신라면을 좋아하지만 느끼한 맛에 지쳤거나  조금 덜 건강을 해치는 라면을 찾는 사람에게도 추천@@
# -긍정키워드-
# #매콤 #스프 #분말
# -부정리뷰-
# 하지만 매번 계란만 먹고 야채만 먹고 그럴 수 없잖아요@@개인적으로 컵누들 매콤한 맛보다 우동맛을 좋아해서 그렇게 맛있지는 않았어요@@
# -부정키워드-
# #우동 #매콤 #개인
# -별점-
# 9.0
# ==================================================
# 컵누들베트남쌀국수
# ==================================================
# -긍정리뷰-
# 종합적인 평가     쌀가루 건면이라 식감이 좋음 뭐 쌀국수니   컵누들의 이미지에서 탈피한 느낌이 강함@@그래도 아주 가끔 진짜 라면이나 쌀국수 같은게 너무 먹고 싶어 못참겠다 하시는 분들께는 꼭 필요할 것 같아요  맛은 있으니까요@@칠리소스는 맛있었다 식당에서 늘 먹는 그 맛@@뭔가 건더기가 되게 많고 크다@@안에 이미 후레이크가 뿌려져 있어요@@그래도 일반 유탕면 컵라면 소컵이 대략 300칼로리니까 다이어트 중에 컵라면이 먹고싶다면  역쉬 컵누들이 좋긴하겠다@@국물  전형적인 쇠고기 쌀국수 육수 맛인데  앞서 말했듯 후추  향신료나 마늘 같은게 좀 있어서 살짝쿵 아린 맛이 났다@@칼로리 자체는 낮지만 양이 적어서 낮은게 아닐까요@@그렇다고 향신료 냄새가 심한건 아니구요@@이게 제일 맛있는 것 같음@@스리라차 소스 째끔 뿌려먹기도 하고 국물까지 순삭했던@@맛은 여러분이 생각하는 딱 그 팟타이 맛인데  달달한 맛이 좀 더 강해요@@향신료의 맛은 한국인들이 대중적으로 부담없이 먹을 수 있는 정도이다@@재구매 의사가 있다@@10월에 친오빠가 결혼하는데 다이어트는 해야될것 같고 하지만 배는고프고 라면은 먹고싶고    그래서 고르게된 칼로리가 낮은 컵누들@@라면 먹고싶은데 칼로리 걱정될때 가끔먹는것도 좋을것 같애요@@
# -긍정키워드-
# #칼로리 #쌀국수 #향신료
# -부정리뷰-
# 다만 가격이 좀 사악하다라는게 단점이랄까@@포만감을 느끼기엔 살짝 무리데스@@당면은 GI지수가 높아 다이어트에 좋지 않음@@맛있지만 양이 적어서 아쉬웠다@@
# -부정키워드-
# #아쉽 #양이 #다이어트
# -별점-
# 8.0
# ==================================================
# 크림진짬뽕
# ==================================================
# -긍정리뷰-
# 꾸덕꾸덕 오뚜기 크림진짬뽕 컵라면을 한마디로 요약하면  매운로제 소스 비빔라면 이라고 할 수 있겠다@@진짜로 꾸덕꾸덕한 식감이 잘 느껴진다@@살짝 매콤한 맛이 나면서 짠맛이 나는 스프@@진짬뽕의 불맛도 느껴지는 오묘한 스타일이긴 한데 중독성은 있다@@신라면 정도이지만 입에 오래남지 않고 금방 사라지는 매운맛이예요@@생각보다 정말 맛있었어요@@엄마가 한 입 드셔보시고는 매운맛이 덜하고 덜 자극적이라 아주 맛있다고 하시더라구용@@맵기는 까르보불닭보다 덜 매워서 매운걸 잘 못드시는 분들도 충분히 드실 수 있을 것 같아요@@꾸덕한 식감과 크림 파스타 좋아하신다면 기대할 만도@@베이스 자체가 짬뽕 맛이라 느끼한 건 딱히 없네요@@한젓가락 시식해보니 살짝 매콤하면서도 담백하고 깊은 우유크림의 맛이 느껴져서 새로웠어요@@짬뽕의 식감을 주기 위해 엄청 두꺼워요@@두꺼운 면 덕분에 스프의 맛이 제대로 느껴지고 식감도 훠얼씬 좋아요      한 젓가락 하실라예@@암튼 여러분  혹시나 크림진짬뽕을 컵라면으로만 드셔보시고 만족하셨다면  다음은 봉지라면으로 저처럼 해서 드셔보셔요@@불닭만큼 자극적이지도 않고  맵찔인 내가 먹었을때 하나도 맵진 않았음@@근데바밥을 비벼먹을 자신은 없었습니닼@@
# -긍정키워드-
# #크림 #짬뽕 #느끼
# -부정리뷰-
# 마냥 달달한 치즈향은 아니고 약간 비릿하기도 한 그런 향이다@@단맛만 좀 줄고 크림맛이 더 풍성했으면 좋았을텐데  단맛이 너무 강한 게 좀 아쉬웠어요@@양념도 뭔가 진하지 않은 싱거운 느낌이였거든요@@스프들이 들어가니 향이 좋더라구욬@@
# -부정키워드-
# #단맛 #싱겁 #진하
# -별점-
# 8.0
